# %% [markdown]
# <a href="https://colab.research.google.com/github/tarik19x/Deep-Neural-Networks-with-PyTorch/blob/main/Linear%20Regression/Stochastic_Gradient_Descent_and_the_Data_Loader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1>Linear regression 1D: Training Two Parameter Stochastic Gradient Descent (SGD)</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use SGD(Stochastic Gradient Descent) to train the model.</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this Lab, you will practice training a model by using Stochastic Gradient descent.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#Model_Cost">Create the Model and Cost Function (Total Loss)</a></li>
#     <li><a href="#BGD">Train the Model:Batch Gradient Descent</a></li>
#     <li><a href="#SGD">Train the Model:Stochastic gradient descent</a></li>
#     <li><a href="#SGD_Loader">Train the Model:Stochastic gradient descent with Data Loader</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries:

# %%
# These are the libraries we are going to use in the lab.

import torch
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits import mplot3d

# %% [markdown]
# The class <code>plot_error_surfaces</code> is just to help you visualize the data space and the parameter space during training and has nothing to do with PyTorch.

# %%
# The class for plot the diagram

class plot_error_surfaces(object):
    
    # Constructor
    def __init__(self, w_range, b_range, X, Y, n_samples = 30, go = True):
        W = np.linspace(-w_range, w_range, n_samples)
        B = np.linspace(-b_range, b_range, n_samples)
        w, b = np.meshgrid(W, B)    
        Z = np.zeros((30, 30))
        count1 = 0
        self.y = Y.numpy()
        self.x = X.numpy()
        for w1, b1 in zip(w, b):
            count2 = 0
            for w2, b2 in zip(w1, b1):
                Z[count1, count2] = np.mean((self.y - w2 * self.x + b2) ** 2)
                count2 += 1
            count1 += 1
        self.Z = Z
        self.w = w
        self.b = b
        self.W = []
        self.B = []
        self.LOSS = []
        self.n = 0
        if go == True:
            plt.figure()
            plt.figure(figsize = (7.5, 5))
            plt.axes(projection = '3d').plot_surface(self.w, self.b, self.Z, rstride = 1, cstride = 1,cmap = 'viridis', edgecolor = 'none')
            plt.title('Loss Surface')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.show()
            plt.figure()
            plt.title('Loss Surface Contour')
            plt.xlabel('w')
            plt.ylabel('b')
            plt.contour(self.w, self.b, self.Z)
            plt.show()
    
    # Setter
    def set_para_loss(self, W, B, loss):
        self.n = self.n + 1
        self.W.append(W)
        self.B.append(B)
        self.LOSS.append(loss)
    
    # Plot diagram
    def final_plot(self): 
        ax = plt.axes(projection = '3d')
        ax.plot_wireframe(self.w, self.b, self.Z)
        ax.scatter(self.W, self.B, self.LOSS, c = 'r', marker = 'x', s = 200, alpha = 1)
        plt.figure()
        plt.contour(self.w, self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()
    
    # Plot diagram
    def plot_ps(self):
        plt.subplot(121)
        plt.ylim
        plt.plot(self.x, self.y, 'ro', label = "training points")
        plt.plot(self.x, self.W[-1] * self.x + self.B[-1], label = "estimated line")
        plt.xlabel('x')
        plt.ylabel('y')
        plt.ylim((-10, 15))
        plt.title('Data Space Iteration: ' + str(self.n))
        plt.subplot(122)
        plt.contour(self.w, self.b, self.Z)
        plt.scatter(self.W, self.B, c = 'r', marker = 'x')
        plt.title('Loss Surface Contour Iteration' + str(self.n))
        plt.xlabel('w')
        plt.ylabel('b')
        plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# Set random seed:

# %%
# Set random seed

torch.manual_seed(1)

# %% [markdown]
# Generate values from <i>-3</i> to <i>3</i> that create a line with a slope of <i>1</i> and a bias of <i>-1</i>. This is the line that you need to estimate. Add some noise to the data:

# %%
# Setup the actual data and simulated data

X = torch.arange(-3, 3, 0.1).view(-1, 1)
f = 1 * X - 1
Y = f + 0.1 * torch.randn(X.size())

# %% [markdown]
# Plot the results:

# %%
# Plot out the data dots and line

plt.plot(X.numpy(), Y.numpy(), 'rx', label = 'y')
plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model_Cost">Create the Model and Cost Function (Total Loss)</h2>

# %% [markdown]
# Define the <code>forward</code> function:

# %%
# Define the forward function

def forward(x):
    return w * x + b

# %% [markdown]
# Define the cost or criterion function (MSE):

# %%
# Define the MSE Loss function

def criterion(yhat, y):
    return torch.mean((yhat - y) ** 2)

# %% [markdown]
# Create a <code> plot_error_surfaces</code> object to visualize the data space and the parameter space during training:

# %%
# Create plot_error_surfaces for viewing the data

get_surface = plot_error_surfaces(15, 13, X, Y, 30)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="BGD">Train the Model: Batch Gradient Descent</h2>

# %% [markdown]
# Create model parameters <code>w</code>, <code>b</code> by setting the argument <code>requires_grad</code> to True because the system must learn it.

# %%
# Define the parameters w, b for y = wx + b

w = torch.tensor(-15.0, requires_grad = True)
b = torch.tensor(-10.0, requires_grad = True)

# %% [markdown]
# Set the learning rate to  0.1 and create an empty list <code>LOSS</code> for storing the loss for each iteration.

# %%
# Define learning rate and create an empty list for containing the loss for each iteration.

lr = 0.1
LOSS_BGD = []

# %% [markdown]
# Define <code>train_model</code> function for train the model.

# %%
# The function for training the model

def train_model(iter):
    
    # Loop
    for epoch in range(iter):
        
        # make a prediction
        Yhat = forward(X)
        
        # calculate the loss 
        loss = criterion(Yhat, Y)

        # Section for plotting
        get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
        get_surface.plot_ps()
            
        # store the loss in the list LOSS_BGD
        LOSS_BGD.append(loss)
        
        # backward pass: compute gradient of the loss with respect to all the learnable parameters
        loss.backward()
        
        # update parameters slope and bias
        w.data = w.data - lr * w.grad.data
        b.data = b.data - lr * b.grad.data
        
        # zero the gradients before running the backward pass
        w.grad.data.zero_()
        b.grad.data.zero_()

# %% [markdown]
# Run 10 epochs of batch gradient descent: <b>bug</b> data space is 1 iteration ahead of parameter space.

# %%
# Train the model with 10 iterations

train_model(10)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="SGD">Train the Model: Stochastic Gradient Descent</h2>

# %% [markdown]
# Create a <code>plot_error_surfaces</code> object to visualize the data space and the parameter space during training:

# %%
# Create plot_error_surfaces for viewing the data

get_surface = plot_error_surfaces(15, 13, X, Y, 30, go = False)

# %% [markdown]
# Define <code>train_model_SGD</code> function for training the model.

# %%
# The function for training the model

LOSS_SGD = []
w = torch.tensor(-15.0, requires_grad = True)
b = torch.tensor(-10.0, requires_grad = True)

def train_model_SGD(iter):
    
    # Loop
    for epoch in range(iter):
        
        # SGD is an approximation of out true total loss/cost, in this line of code we calculate our true loss/cost and store it
        Yhat = forward(X)

        # store the loss 
        LOSS_SGD.append(criterion(Yhat, Y).tolist())
        
        for x, y in zip(X, Y):
            
            # make a pridiction
            yhat = forward(x)
        
            # calculate the loss 
            loss = criterion(yhat, y)

            # Section for plotting
            get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
        
            # backward pass: compute gradient of the loss with respect to all the learnable parameters
            loss.backward()
        
            # update parameters slope and bias
            w.data = w.data - lr * w.grad.data
            b.data = b.data - lr * b.grad.data

            # zero the gradients before running the backward pass
            w.grad.data.zero_()
            b.grad.data.zero_()
            
        #plot surface and data space after each epoch    
        get_surface.plot_ps()

# %% [markdown]
# Run 10 epochs of stochastic gradient descent: <b>bug</b> data space is 1 iteration ahead of parameter space.

# %%
# Train the model with 10 iterations

train_model_SGD(10)

# %% [markdown]
# Compare the loss of both batch gradient descent as SGD.

# %%
# Plot out the LOSS_BGD and LOSS_SGD

plt.plot(LOSS_BGD,label = "Batch Gradient Descent")
plt.plot(LOSS_SGD,label = "Stochastic Gradient Descent")
plt.xlabel('epoch')
plt.ylabel('Cost/ total loss')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="SGD_Loader">SGD with Dataset DataLoader</h2>

# %% [markdown]
# Import the module for building a dataset class:

# %%
# Import the library for DataLoader

from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# Create a dataset class:

# %%
# Dataset Class

class Data(Dataset):
    
    # Constructor
    def __init__(self):
        self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
        self.y = 1 * self.x - 1
        self.len = self.x.shape[0]
        
    # Getter
    def __getitem__(self,index):    
        return self.x[index], self.y[index]
    
    # Return the length
    def __len__(self):
        return self.len

# %% [markdown]
# Create a dataset object and check the length of the dataset.

# %%
# Create the dataset and check the length

dataset = Data()
print("The length of dataset: ", len(dataset))
# Out:
# The length of dataset:  60

# %% [markdown]
# Obtain the first training point:

# %%
# Print the first point

x, y = dataset[0]
print("(", x, ", ", y, ")")
# Out:
# ( tensor([-3.]) ,  tensor([-4.]) )

# %% [markdown]
# Similarly, obtain the first three training points:

# %%
# Print the first 3 point

x, y = dataset[0:3]
print("The first 3 x: ", x)
print("The first 3 y: ", y)
# Out:
# The first 3 x:  tensor([[-3.0000],
#         [-2.9000],
#         [-2.8000]])
# The first 3 y:  tensor([[-4.0000],
#         [-3.9000],
#         [-3.8000]])

# %% [markdown]
# Create a <code>plot_error_surfaces</code> object to visualize the data space and the parameter space during training:

# %%
# Create plot_error_surfaces for viewing the data

get_surface = plot_error_surfaces(15, 13, X, Y, 30, go = False)

# %% [markdown]
# Create a <code>DataLoader</code> object by using the constructor:

# %%
# Create DataLoader

trainloader = DataLoader(dataset = dataset, batch_size = 1)
x
# Out:
# tensor([[-3.0000],
#         [-2.9000],
#         [-2.8000]])

# %% [markdown]
# Define <code>train_model_DataLoader</code> function for training the model.

# %%
# The function for training the model

w = torch.tensor(-15.0,requires_grad=True)
b = torch.tensor(-10.0,requires_grad=True)
LOSS_Loader = []

def train_model_DataLoader(epochs):
    
    # Loop
    for epoch in range(epochs):
        
        # SGD is an approximation of out true total loss/cost, in this line of code we calculate our true loss/cost and store it
        Yhat = forward(X)
        
        # store the loss 
        LOSS_Loader.append(criterion(Yhat, Y).tolist())
        
        for x, y in trainloader:
            
            # make a prediction
            yhat = forward(x)
            
            # calculate the loss
            loss = criterion(yhat, y)
            
            # Section for plotting
            get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
            
            # Backward pass: compute gradient of the loss with respect to all the learnable parameters
            loss.backward()
            
            # Updata parameters slope
            w.data = w.data - lr * w.grad.data
            b.data = b.data - lr* b.grad.data
            
            # Clear gradients 
            w.grad.data.zero_()
            b.grad.data.zero_()
            
        #plot surface and data space after each epoch    
        get_surface.plot_ps()

# %% [markdown]
# Run 10 epochs of stochastic gradient descent: <b>bug</b> data space is 1 iteration ahead of parameter space.

# %%
# Run 10 iterations

train_model_DataLoader(10)

# %% [markdown]
# Compare the loss of both batch gradient decent as SGD. Note that SGD converges to a minimum faster, that is, it decreases faster.

# %%
# Plot the LOSS_BGD and LOSS_Loader

plt.plot(LOSS_BGD,label="Batch Gradient Descent")
plt.plot(LOSS_Loader,label="Stochastic Gradient Descent with DataLoader")
plt.xlabel('epoch')
plt.ylabel('Cost/ total loss')
plt.legend()
plt.show()

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# For practice, try to use SGD with DataLoader to train model with 10 iterations. Store the total loss in <code>LOSS</code>. We are going to use it in the next question.

# %%
# Practice: Use SGD with trainloader to train model and store the total loss in LOSS

LOSS = []
w = torch.tensor(-12.0, requires_grad = True)
b = torch.tensor(-10.0, requires_grad = True)

def train_model_DataLoader(epochs):

  for epoch in range(epochs):

     Yhat = forward(X)
     print("Yhat : ", Yhat)
     print("criterion(Yhat, Y).tolist() : ", criterion(Yhat, Y).tolist())
     LOSS_Loader.append(criterion(Yhat, Y).tolist())
     for x, y in trainloader:

       yhat = forward(x)
       loss = criterion(yhat, y)
       print("loss : ", loss)
       get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
       loss.backward()
       w.data = w.data - lr * w.grad.data
       b.data = b.data - lr* b.grad.data
            
       # Clear gradients 
       w.grad.data.zero_()
       b.grad.data.zero_()
       
     get_surface.plot_ps()

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# def my_train_model(epochs):
#     for epoch in range(epochs):
#         Yhat = forward(X)
#         LOSS.append(criterion(Yhat, X))
#         for x, y in trainloader:
#             yhat = forward(x)
#             loss = criterion(yhat, y)
#             get_surface.set_para_loss(w.data.tolist(), b.data.tolist(), loss.tolist())
#             loss.backward()
#             w.data = w.data - lr * w.grad.data
#             b.data = b.data - lr * b.grad.data
#             w.grad.data.zero_()
#             b.grad.data.zero_()
#         get_surface.plot_ps()
# my_train_model(10)
# -->

# %% [markdown]
# Plot the total loss

# %%
# Practice: Plot the total loss using LOSS
train_model_DataLoader(10)
# Type your code here
# Out:
# Yhat :  tensor([[-4.0229],
#         [-3.9226],
#         [-3.8222],
#         [-3.7218],
#         [-3.6214],
#         [-3.5210],
#         [-3.4206],
#         [-3.3202],
#         [-3.2199],
#         [-3.1195],
#         [-3.0191],
#         [-2.9187],
#         [-2.8183],
#         [-2.7179],
#         [-2.6175],
#         [-2.5172],
#         [-2.4168],
#         [-2.3164],
#         [-2.2160],
#         [-2.1156],
#         [-2.0152],
#         [-1.9148],
#         [-1.8145],
#         [-1.7141],
#         [-1.6137],
#         [-1.5133],
#         [-1.4129],
#         [-1.3125],
#         [-1.2121],
#         [-1.1118],
#         [-1.0114],
#         [-0.9110],
#         [-0.8106],
#         [-0.7102],
#         [-0.6098],
#         [-0.5094],
#         [-0.4091],
#         [-0.3087],
#         [-0.2083],
#         [-0.1079],
#         [-0.0075],
#         [ 0.0929],
#         [ 0.1933],
#         [ 0.2936],
#         [ 0.3940],
#         [ 0.4944],
#         [ 0.5948],
#         [ 0.6952],
#         [ 0.7956],
#         [ 0.8960],
#         [ 0.9963],
#         [ 1.0967],
#         [ 1.1971],
#         [ 1.2975],
#         [ 1.3979],
#         [ 1.4983],
#         [ 1.5987],
#         [ 1.6990],
#         [ 1.7994],
#         [ 1.8998]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.00784755777567625
# loss :  tensor(0.0005, grad_fn=<MeanBackward0>)
# loss :  tensor(0.0005, grad_fn=<MeanBackward0>)
# loss :  tensor(0.0004, grad_fn=<MeanBackward0>)
# loss :  tensor(0.0002, grad_fn=<MeanBackward0>)
# loss :  tensor(8.3946e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0646e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4348e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7808e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3795e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0161e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5029e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8458e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2965e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8700e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6041e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(4.5332e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.7193e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.2325e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(9.1587e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1593e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4675e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8543e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3349e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9255e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6425e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4945e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4838e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(6.6008e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(7.8119e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0653e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0278e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1342e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2138e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2545e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2468e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1867e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0773e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(9.2943e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(7.5988e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(5.8795e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(4.3087e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0021e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0048e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2999e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(8.3209e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.3601e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5300e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4017e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6905e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2250e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0962e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8656e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.2824e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0925e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2316e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5441e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0532e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6576e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3481e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1030e-08, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-3.9888e+00],
#         [-3.8890e+00],
#         [-3.7892e+00],
#         [-3.6894e+00],
#         [-3.5896e+00],
#         [-3.4897e+00],
#         [-3.3899e+00],
#         [-3.2901e+00],
#         [-3.1903e+00],
#         [-3.0905e+00],
#         [-2.9907e+00],
#         [-2.8909e+00],
#         [-2.7911e+00],
#         [-2.6913e+00],
#         [-2.5914e+00],
#         [-2.4916e+00],
#         [-2.3918e+00],
#         [-2.2920e+00],
#         [-2.1922e+00],
#         [-2.0924e+00],
#         [-1.9926e+00],
#         [-1.8928e+00],
#         [-1.7929e+00],
#         [-1.6931e+00],
#         [-1.5933e+00],
#         [-1.4935e+00],
#         [-1.3937e+00],
#         [-1.2939e+00],
#         [-1.1941e+00],
#         [-1.0943e+00],
#         [-9.9445e-01],
#         [-8.9464e-01],
#         [-7.9483e-01],
#         [-6.9502e-01],
#         [-5.9520e-01],
#         [-4.9539e-01],
#         [-3.9558e-01],
#         [-2.9577e-01],
#         [-1.9596e-01],
#         [-9.6145e-02],
#         [ 3.6669e-03],
#         [ 1.0348e-01],
#         [ 2.0329e-01],
#         [ 3.0310e-01],
#         [ 4.0291e-01],
#         [ 5.0273e-01],
#         [ 6.0254e-01],
#         [ 7.0235e-01],
#         [ 8.0216e-01],
#         [ 9.0197e-01],
#         [ 1.0018e+00],
#         [ 1.1016e+00],
#         [ 1.2014e+00],
#         [ 1.3012e+00],
#         [ 1.4010e+00],
#         [ 1.5008e+00],
#         [ 1.6007e+00],
#         [ 1.7005e+00],
#         [ 1.8003e+00],
#         [ 1.9001e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008706980384886265
# loss :  tensor(0.0001, grad_fn=<MeanBackward0>)
# loss :  tensor(0.0001, grad_fn=<MeanBackward0>)
# loss :  tensor(8.6627e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(4.5757e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9975e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9132e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2934e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(4.2335e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6616e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4090e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5836e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.3920e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4704e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8406e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(8.5579e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0794e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3621e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7190e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1770e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7587e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4933e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4137e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.5564e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9653e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(8.6681e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0697e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3050e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5703e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8589e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1570e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4452e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6987e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8879e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9847e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9664e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8233e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5628e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2110e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8078e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3987e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0250e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(7.1415e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(4.7674e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0913e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9793e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2747e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(8.3983e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.7128e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0156e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9182e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1570e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6331e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2610e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(9.7427e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.6562e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(6.0968e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.8467e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9468e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1660e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6767e-09, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-4.0055e+00],
#         [-3.9054e+00],
#         [-3.8053e+00],
#         [-3.7052e+00],
#         [-3.6051e+00],
#         [-3.5050e+00],
#         [-3.4049e+00],
#         [-3.3048e+00],
#         [-3.2047e+00],
#         [-3.1046e+00],
#         [-3.0045e+00],
#         [-2.9044e+00],
#         [-2.8044e+00],
#         [-2.7043e+00],
#         [-2.6042e+00],
#         [-2.5041e+00],
#         [-2.4040e+00],
#         [-2.3039e+00],
#         [-2.2038e+00],
#         [-2.1037e+00],
#         [-2.0036e+00],
#         [-1.9035e+00],
#         [-1.8034e+00],
#         [-1.7033e+00],
#         [-1.6033e+00],
#         [-1.5032e+00],
#         [-1.4031e+00],
#         [-1.3030e+00],
#         [-1.2029e+00],
#         [-1.1028e+00],
#         [-1.0027e+00],
#         [-9.0261e-01],
#         [-8.0252e-01],
#         [-7.0243e-01],
#         [-6.0234e-01],
#         [-5.0225e-01],
#         [-4.0216e-01],
#         [-3.0206e-01],
#         [-2.0197e-01],
#         [-1.0188e-01],
#         [-1.7886e-03],
#         [ 9.8303e-02],
#         [ 1.9839e-01],
#         [ 2.9849e-01],
#         [ 3.9858e-01],
#         [ 4.9867e-01],
#         [ 5.9876e-01],
#         [ 6.9885e-01],
#         [ 7.9895e-01],
#         [ 8.9904e-01],
#         [ 9.9913e-01],
#         [ 1.0992e+00],
#         [ 1.1993e+00],
#         [ 1.2994e+00],
#         [ 1.3995e+00],
#         [ 1.4996e+00],
#         [ 1.5997e+00],
#         [ 1.6998e+00],
#         [ 1.7999e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008189127780497074
# loss :  tensor(2.9788e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7270e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0600e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0883e-05, grad_fn=<MeanBackward0>)
# loss :  tensor(4.7508e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1680e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0754e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0075e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3481e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.7121e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(8.5134e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0413e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2988e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6270e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5670e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2316e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0973e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1734e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(6.5568e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(8.2950e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0491e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3220e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6563e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0618e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5427e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1019e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.7369e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4200e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1296e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.8153e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.4183e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8691e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.1003e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.0551e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.7159e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.0959e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(5.2593e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(4.3003e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.3283e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4386e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6993e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1345e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.3582e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.7098e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0354e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9955e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3620e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(9.5554e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9236e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1586e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9020e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9679e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3194e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8213e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4461e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1543e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.4593e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(7.5175e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(6.2670e-10, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-3.9973e+00],
#         [-3.8974e+00],
#         [-3.7974e+00],
#         [-3.6975e+00],
#         [-3.5975e+00],
#         [-3.4976e+00],
#         [-3.3976e+00],
#         [-3.2977e+00],
#         [-3.1977e+00],
#         [-3.0977e+00],
#         [-2.9978e+00],
#         [-2.8978e+00],
#         [-2.7979e+00],
#         [-2.6979e+00],
#         [-2.5980e+00],
#         [-2.4980e+00],
#         [-2.3981e+00],
#         [-2.2981e+00],
#         [-2.1981e+00],
#         [-2.0982e+00],
#         [-1.9982e+00],
#         [-1.8983e+00],
#         [-1.7983e+00],
#         [-1.6984e+00],
#         [-1.5984e+00],
#         [-1.4985e+00],
#         [-1.3985e+00],
#         [-1.2985e+00],
#         [-1.1986e+00],
#         [-1.0986e+00],
#         [-9.9868e-01],
#         [-8.9872e-01],
#         [-7.9877e-01],
#         [-6.9881e-01],
#         [-5.9886e-01],
#         [-4.9890e-01],
#         [-3.9895e-01],
#         [-2.9899e-01],
#         [-1.9904e-01],
#         [-9.9083e-02],
#         [ 8.7231e-04],
#         [ 1.0083e-01],
#         [ 2.0078e-01],
#         [ 3.0074e-01],
#         [ 4.0069e-01],
#         [ 5.0065e-01],
#         [ 6.0060e-01],
#         [ 7.0056e-01],
#         [ 8.0051e-01],
#         [ 9.0047e-01],
#         [ 1.0004e+00],
#         [ 1.1004e+00],
#         [ 1.2003e+00],
#         [ 1.3003e+00],
#         [ 1.4002e+00],
#         [ 1.5002e+00],
#         [ 1.6002e+00],
#         [ 1.7001e+00],
#         [ 1.8001e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008418220095336437
# loss :  tensor(7.0885e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(6.4898e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9027e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5899e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1307e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7788e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.3098e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4122e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2470e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3657e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0305e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4830e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1125e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.8722e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.8467e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(6.1154e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.6980e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.7427e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2291e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5608e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9787e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4949e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1423e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9443e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9005e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(6.0540e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(7.3874e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(8.8818e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0521e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2208e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3838e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5275e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6346e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6890e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6787e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5977e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4502e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2510e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0237e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(7.9216e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.8043e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0444e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7024e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7509e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1206e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(7.1839e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.7641e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2470e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2624e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6331e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2200e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.3132e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9407e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6276e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.2532e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4584e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7457e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2921e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7195e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5370e-10, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-4.0013e+00],
#         [-3.9013e+00],
#         [-3.8013e+00],
#         [-3.7012e+00],
#         [-3.6012e+00],
#         [-3.5012e+00],
#         [-3.4012e+00],
#         [-3.3011e+00],
#         [-3.2011e+00],
#         [-3.1011e+00],
#         [-3.0011e+00],
#         [-2.9011e+00],
#         [-2.8010e+00],
#         [-2.7010e+00],
#         [-2.6010e+00],
#         [-2.5010e+00],
#         [-2.4009e+00],
#         [-2.3009e+00],
#         [-2.2009e+00],
#         [-2.1009e+00],
#         [-2.0009e+00],
#         [-1.9008e+00],
#         [-1.8008e+00],
#         [-1.7008e+00],
#         [-1.6008e+00],
#         [-1.5008e+00],
#         [-1.4007e+00],
#         [-1.3007e+00],
#         [-1.2007e+00],
#         [-1.1007e+00],
#         [-1.0006e+00],
#         [-9.0062e-01],
#         [-8.0060e-01],
#         [-7.0058e-01],
#         [-6.0056e-01],
#         [-5.0053e-01],
#         [-4.0051e-01],
#         [-3.0049e-01],
#         [-2.0047e-01],
#         [-1.0045e-01],
#         [-4.2558e-04],
#         [ 9.9596e-02],
#         [ 1.9962e-01],
#         [ 2.9964e-01],
#         [ 3.9966e-01],
#         [ 4.9968e-01],
#         [ 5.9971e-01],
#         [ 6.9973e-01],
#         [ 7.9975e-01],
#         [ 8.9977e-01],
#         [ 9.9979e-01],
#         [ 1.0998e+00],
#         [ 1.1998e+00],
#         [ 1.2999e+00],
#         [ 1.3999e+00],
#         [ 1.4999e+00],
#         [ 1.5999e+00],
#         [ 1.6999e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008300884626805782
# loss :  tensor(1.6859e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5430e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1660e-06, grad_fn=<MeanBackward0>)
# loss :  tensor(6.1565e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6866e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.6057e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7383e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(5.7986e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(7.7813e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1974e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.8112e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.9140e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(7.2583e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(9.1683e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1787e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4371e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8010e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3425e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9549e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.7253e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.6821e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(5.9304e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.4696e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.3698e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1691e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4411e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7572e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1186e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5062e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9060e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2919e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6334e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.8877e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0180e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9918e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.8035e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4539e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9775e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4350e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8827e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3816e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(9.6371e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(6.4365e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.1669e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6644e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7259e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1301e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.7481e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4037e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9159e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9468e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2204e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6576e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3097e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1005e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(7.7819e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.7658e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9468e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.6171e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2742e-11, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-3.9994e+00],
#         [-3.8994e+00],
#         [-3.7994e+00],
#         [-3.6994e+00],
#         [-3.5994e+00],
#         [-3.4994e+00],
#         [-3.3994e+00],
#         [-3.2994e+00],
#         [-3.1995e+00],
#         [-3.0995e+00],
#         [-2.9995e+00],
#         [-2.8995e+00],
#         [-2.7995e+00],
#         [-2.6995e+00],
#         [-2.5995e+00],
#         [-2.4995e+00],
#         [-2.3995e+00],
#         [-2.2995e+00],
#         [-2.1996e+00],
#         [-2.0996e+00],
#         [-1.9996e+00],
#         [-1.8996e+00],
#         [-1.7996e+00],
#         [-1.6996e+00],
#         [-1.5996e+00],
#         [-1.4996e+00],
#         [-1.3996e+00],
#         [-1.2997e+00],
#         [-1.1997e+00],
#         [-1.0997e+00],
#         [-9.9969e-01],
#         [-8.9970e-01],
#         [-7.9971e-01],
#         [-6.9972e-01],
#         [-5.9973e-01],
#         [-4.9974e-01],
#         [-3.9975e-01],
#         [-2.9976e-01],
#         [-1.9977e-01],
#         [-9.9782e-02],
#         [ 2.0748e-04],
#         [ 1.0020e-01],
#         [ 2.0019e-01],
#         [ 3.0018e-01],
#         [ 4.0016e-01],
#         [ 5.0015e-01],
#         [ 6.0014e-01],
#         [ 7.0013e-01],
#         [ 8.0012e-01],
#         [ 9.0011e-01],
#         [ 1.0001e+00],
#         [ 1.1001e+00],
#         [ 1.2001e+00],
#         [ 1.3001e+00],
#         [ 1.4001e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008356794714927673
# loss :  tensor(4.0129e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6731e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7738e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4661e-07, grad_fn=<MeanBackward0>)
# loss :  tensor(6.3869e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5608e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(4.0827e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2557e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7195e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(8.2082e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1511e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3648e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7826e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2561e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7063e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4584e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4020e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.5712e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(7.0037e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(8.7402e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1301e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4190e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7808e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2285e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7889e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4399e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.1901e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(5.0310e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(5.9672e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9038e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.8345e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(8.6459e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.2548e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.5554e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.5088e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0495e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(8.2082e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.0832e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(5.7935e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4804e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2878e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2965e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5382e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.9796e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(6.3268e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.1069e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7063e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8146e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3097e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.1637e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.2879e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9918e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2742e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2790e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4552e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(9.6065e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(8.8818e-12, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-4.0003e+00],
#         [-3.9003e+00],
#         [-3.8003e+00],
#         [-3.7003e+00],
#         [-3.6003e+00],
#         [-3.5003e+00],
#         [-3.4003e+00],
#         [-3.3003e+00],
#         [-3.2003e+00],
#         [-3.1003e+00],
#         [-3.0003e+00],
#         [-2.9003e+00],
#         [-2.8002e+00],
#         [-2.7002e+00],
#         [-2.6002e+00],
#         [-2.5002e+00],
#         [-2.4002e+00],
#         [-2.3002e+00],
#         [-2.2002e+00],
#         [-2.1002e+00],
#         [-2.0002e+00],
#         [-1.9002e+00],
#         [-1.8002e+00],
#         [-1.7002e+00],
#         [-1.6002e+00],
#         [-1.5002e+00],
#         [-1.4002e+00],
#         [-1.3002e+00],
#         [-1.2002e+00],
#         [-1.1002e+00],
#         [-1.0002e+00],
#         [-9.0015e-01],
#         [-8.0014e-01],
#         [-7.0014e-01],
#         [-6.0013e-01],
#         [-5.0013e-01],
#         [-4.0012e-01],
#         [-3.0012e-01],
#         [-2.0011e-01],
#         [-1.0011e-01],
#         [-1.0133e-04],
#         [ 9.9904e-02],
#         [ 1.9991e-01],
#         [ 2.9991e-01],
#         [ 3.9992e-01],
#         [ 4.9992e-01],
#         [ 5.9993e-01],
#         [ 6.9994e-01],
#         [ 7.9994e-01],
#         [ 8.9995e-01],
#         [ 9.9995e-01],
#         [ 1.1000e+00],
#         [ 1.2000e+00],
#         [ 1.3000e+00],
#         [ 1.4000e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008329201489686966
# loss :  tensor(9.5475e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(8.7262e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(6.5934e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4850e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5252e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(3.7253e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.6065e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0070e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.1439e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6428e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7512e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2742e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4565e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4627e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.5711e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(8.2082e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0027e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3097e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6576e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1151e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6284e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4142e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.2041e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.3484e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(6.6302e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(8.1855e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(9.9044e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2034e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4190e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6525e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8726e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0575e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2060e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2794e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2624e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1504e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9507e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6865e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.3789e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0669e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(7.7813e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4314e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6153e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3465e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5076e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(9.6723e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.3793e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.3773e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0727e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1615e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6428e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1951e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0360e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8781e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(6.2670e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1301e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.1974e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7853e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4016e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-12, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-3.9998e+00],
#         [-3.8999e+00],
#         [-3.7999e+00],
#         [-3.6999e+00],
#         [-3.5999e+00],
#         [-3.4999e+00],
#         [-3.3999e+00],
#         [-3.2999e+00],
#         [-3.1999e+00],
#         [-3.0999e+00],
#         [-2.9999e+00],
#         [-2.8999e+00],
#         [-2.7999e+00],
#         [-2.6999e+00],
#         [-2.5999e+00],
#         [-2.4999e+00],
#         [-2.3999e+00],
#         [-2.2999e+00],
#         [-2.1999e+00],
#         [-2.0999e+00],
#         [-1.9999e+00],
#         [-1.8999e+00],
#         [-1.7999e+00],
#         [-1.6999e+00],
#         [-1.5999e+00],
#         [-1.4999e+00],
#         [-1.3999e+00],
#         [-1.2999e+00],
#         [-1.1999e+00],
#         [-1.0999e+00],
#         [-9.9993e-01],
#         [-8.9993e-01],
#         [-7.9993e-01],
#         [-6.9993e-01],
#         [-5.9994e-01],
#         [-4.9994e-01],
#         [-3.9994e-01],
#         [-2.9994e-01],
#         [-1.9995e-01],
#         [-9.9948e-02],
#         [ 4.9472e-05],
#         [ 1.0005e-01],
#         [ 2.0004e-01],
#         [ 3.0004e-01],
#         [ 4.0004e-01],
#         [ 5.0004e-01],
#         [ 6.0003e-01],
#         [ 7.0003e-01],
#         [ 8.0003e-01],
#         [ 9.0003e-01],
#         [ 1.0000e+00],
#         [ 1.1000e+00],
#         [ 1.2000e+00],
#         [ 1.3000e+00],
#         [ 1.4000e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008342597633600235
# loss :  tensor(2.2849e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1013e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5907e-08, grad_fn=<MeanBackward0>)
# loss :  tensor(8.3819e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6673e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0245e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3283e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8781e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1141e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.6043e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(8.1855e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1141e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2790e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4552e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0520e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7512e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0070e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.8426e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.5711e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.9936e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0027e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2557e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.5667e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9122e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4016e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8253e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.4142e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9159e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4521e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9164e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.2660e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.4037e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.3760e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.0763e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(4.6043e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.9396e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2617e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5327e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8468e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2825e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(8.4256e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6403e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6962e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.3888e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6428e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0360e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.5175e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1301e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(4.1069e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7853e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4016e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1511e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5527e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-4.0001e+00],
#         [-3.9001e+00],
#         [-3.8001e+00],
#         [-3.7001e+00],
#         [-3.6001e+00],
#         [-3.5001e+00],
#         [-3.4001e+00],
#         [-3.3001e+00],
#         [-3.2001e+00],
#         [-3.1001e+00],
#         [-3.0001e+00],
#         [-2.9001e+00],
#         [-2.8001e+00],
#         [-2.7001e+00],
#         [-2.6001e+00],
#         [-2.5001e+00],
#         [-2.4001e+00],
#         [-2.3001e+00],
#         [-2.2001e+00],
#         [-2.1000e+00],
#         [-2.0000e+00],
#         [-1.9000e+00],
#         [-1.8000e+00],
#         [-1.7000e+00],
#         [-1.6000e+00],
#         [-1.5000e+00],
#         [-1.4000e+00],
#         [-1.3000e+00],
#         [-1.2000e+00],
#         [-1.1000e+00],
#         [-1.0000e+00],
#         [-9.0004e-01],
#         [-8.0003e-01],
#         [-7.0003e-01],
#         [-6.0003e-01],
#         [-5.0003e-01],
#         [-4.0003e-01],
#         [-3.0003e-01],
#         [-2.0003e-01],
#         [-1.0003e-01],
#         [-2.3961e-05],
#         [ 9.9977e-02],
#         [ 1.9998e-01],
#         [ 2.9998e-01],
#         [ 3.9998e-01],
#         [ 4.9998e-01],
#         [ 5.9998e-01],
#         [ 6.9998e-01],
#         [ 7.9999e-01],
#         [ 8.9999e-01],
#         [ 9.9999e-01],
#         [ 1.1000e+00],
#         [ 1.2000e+00],
#         [ 1.3000e+00],
#         [ 1.4000e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008336045779287815
# loss :  tensor(5.3924e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(4.9133e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(3.7253e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9455e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(8.4606e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7853e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6380e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(4.6043e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6380e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(6.8781e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1141e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2790e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4552e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9455e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5068e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0070e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.8426e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.7805e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6403e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9633e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.7819e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(9.3237e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0510e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1639e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2423e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2825e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2691e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2159e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1130e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(9.5554e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.8874e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(6.0041e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(4.4565e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.2063e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0520e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4101e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(8.8818e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6380e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.4016e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8794e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1511e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5527e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5527e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2790e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# Yhat :  tensor([[-4.0000e+00],
#         [-3.9000e+00],
#         [-3.8000e+00],
#         [-3.7000e+00],
#         [-3.6000e+00],
#         [-3.5000e+00],
#         [-3.4000e+00],
#         [-3.3000e+00],
#         [-3.2000e+00],
#         [-3.1000e+00],
#         [-3.0000e+00],
#         [-2.9000e+00],
#         [-2.8000e+00],
#         [-2.7000e+00],
#         [-2.6000e+00],
#         [-2.5000e+00],
#         [-2.4000e+00],
#         [-2.3000e+00],
#         [-2.2000e+00],
#         [-2.1000e+00],
#         [-2.0000e+00],
#         [-1.9000e+00],
#         [-1.8000e+00],
#         [-1.7000e+00],
#         [-1.6000e+00],
#         [-1.5000e+00],
#         [-1.4000e+00],
#         [-1.3000e+00],
#         [-1.2000e+00],
#         [-1.1000e+00],
#         [-9.9998e-01],
#         [-8.9998e-01],
#         [-7.9998e-01],
#         [-6.9998e-01],
#         [-5.9998e-01],
#         [-4.9999e-01],
#         [-3.9999e-01],
#         [-2.9999e-01],
#         [-1.9999e-01],
#         [-9.9988e-02],
#         [ 1.1742e-05],
#         [ 1.0001e-01],
#         [ 2.0001e-01],
#         [ 3.0001e-01],
#         [ 4.0001e-01],
#         [ 5.0001e-01],
#         [ 6.0001e-01],
#         [ 7.0001e-01],
#         [ 8.0001e-01],
#         [ 9.0001e-01],
#         [ 1.0000e+00],
#         [ 1.1000e+00],
#         [ 1.2000e+00],
#         [ 1.3000e+00],
#         [ 1.4000e+00],
#         [ 1.5000e+00],
#         [ 1.6000e+00],
#         [ 1.7000e+00],
#         [ 1.8000e+00],
#         [ 1.9000e+00]], grad_fn=<AddBackward0>)
# criterion(Yhat, Y).tolist() :  0.008339240215718746
# loss :  tensor(1.3133e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2117e-09, grad_fn=<MeanBackward0>)
# loss :  tensor(9.3132e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.0227e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2561e-10, grad_fn=<MeanBackward0>)
# loss :  tensor(5.8208e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6428e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(9.0949e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1159e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.0464e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(3.6380e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1301e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(6.2670e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(8.1855e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(8.8818e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1141e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4552e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.6428e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.9455e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.1615e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.5068e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8141e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.9420e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0727e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(3.0070e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.8777e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.6276e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.8417e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4101e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(1.0360e-11, grad_fn=<MeanBackward0>)
# loss :  tensor(7.5175e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(5.1301e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(2.7853e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.7195e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(1.1511e-12, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9633e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9633e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(6.9633e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.2790e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(2.2737e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(1.4211e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(3.5527e-13, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)
# loss :  tensor(5.6843e-14, grad_fn=<MeanBackward0>)

# %% [markdown]
# Double-click **here** for the solution.
#
# <!--
# plt.plot(LOSS,label = "Stochastic Gradient Descent")
# plt.xlabel('iteration')
# plt.ylabel('Cost/ total loss')
# plt.legend()
# plt.show()
# -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?context=cpdaas&apps=data_science_experience,watson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"/></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>
#
# Thanks to: Andrew Kin ,Alessandro Barboza

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-23        | 2.0     | Shubham    | Migrated Lab to Markdown and added to course repo in GitLab |

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
